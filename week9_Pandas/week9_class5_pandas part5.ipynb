# %%
import pandas as pd

# %%
#let's create a dictionary:
data={'a':[1,2,3,4],
      'b':[4,5,6,7],
      'c':['muller','neuer','kroos','musiala']}

# %%
#now convert it to data frame:
df=pd.DataFrame(data)
df
# Out:
#    a  b        c
# 0  1  4   muller
# 1  2  5    neuer
# 2  3  6    kroos
# 3  4  7  musiala

# %%
#a column er data column gulo index hisabe treat korbo:
df=df.set_index('a')

# %%
df
# Out:
#    b        c
# a
# 1  4   muller
# 2  5    neuer
# 3  6    kroos
# 4  7  musiala

# %%
#to reset the index again:
df=df.reset_index()
df
# Out:
#    a  b        c
# 0  1  4   muller
# 1  2  5    neuer
# 2  3  6    kroos
# 3  4  7  musiala

# %%
#Now let's say we want to add our own index:
df1=pd.DataFrame(data,index=['a','b','c','d'])
df1
# Out:
#    a  b        c
# a  1  4   muller
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala

# %%
#we want re index it:
df1=df1.reindex(['b','c','d','a'])

# %%
df1
# Out:
#    a  b        c
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala
# a  1  4   muller

# %%
#row by row we try to itterate
#row select korbe , then column wise iter korbe
print(df1)
for i in df1.iterrows():
  print(i)
# Out:
#    a  b        c
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala
# a  1  4   muller
# ('b', a        2
# b        5
# c    neuer
# Name: b, dtype: object)
# ('c', a        3
# b        6
# c    kroos
# Name: c, dtype: object)
# ('d', a          4
# b          7
# c    musiala
# Name: d, dtype: object)
# ('a', a         1
# b         4
# c    muller
# Name: a, dtype: object)

# %%
#now iter items:
#column slect korbe , tar por row wise iter korbe
print(df1)
for i in df1.iteritems():
  print(i)
# Out:
#    a  b        c
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala
# a  1  4   muller
# ('a', b    2
# c    3
# d    4
# a    1
# Name: a, dtype: int64)
# ('b', b    5
# c    6
# d    7
# a    4
# Name: b, dtype: int64)
# ('c', b      neuer
# c      kroos
# d    musiala
# a     muller
# Name: c, dtype: object)
# <ipython-input-11-734c3197e599>:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i in df1.iteritems():

# %%
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# The code [i for i in df['a']] is a list comprehension in Python. It is used to create a new list by iterating over the values in column 'a' of a DataFrame df and appending each value to the new list.

# %%
#to get the same result we can do another thing:
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
print('df1:')
print(df1)
#now see another operation:
print("outcome:")
def test(x):
  return x.sum()
df1.apply(test)
# Out:
# df1:
#    a  b        c
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala
# a  1  4   muller
# outcome:
# a                         10
# b                         22
# c    neuerkroosmusialamuller
# dtype: object

# %%
#another case:
#let's store the numerical values in another dataframe
df2=df1[['a','b']]

# %%
df2
# Out:
#    a  b
# b  2  5
# c  3  6
# d  4  7
# a  1  4

# %%
df2.applymap(lambda x : x**2)
# Out:
#     a   b
# b   4  25
# c   9  36
# d  16  49
# a   1  16

# %% [markdown]
# apply() ta row by row kimba column by column use kora jay , ar applymap() ta puro data frame e

# %%
df1
# Out:
#    a  b        c
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala
# a  1  4   muller

# %%
#now let's sort:
#sorting in alphabatical order
df1.sort_values('c')
# Out:
#    a  b        c
# c  3  6    kroos
# a  1  4   muller
# d  4  7  musiala
# b  2  5    neuer

# %%
#sort based on indexes:
df1.sort_index()
# Out:
#    a  b        c
# a  1  4   muller
# b  2  5    neuer
# c  3  6    kroos
# d  4  7  musiala

# %%
#sort based on indexes:
#in descending order
df1.sort_index(ascending=False)
# Out:
#    a  b        c
# d  4  7  musiala
# c  3  6    kroos
# b  2  5    neuer
# a  1  4   muller

# %%
#ekta dictionary nichii jar value onek boro paragraph
#ebar otake dataframe er moddhe diye pass korabo
df3=pd.DataFrame({'description':[" Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills in students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical, and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science, data analytics, and big data industry including cloud infrastructure and real-time industry projects."]})

# %%
df3
# Out:
#                                          description
# 0   Data Science Masters course is highly curated...

# %%
#dekho puro ta dekha jachhe na
#solution:
pd.set_option('display.max_colwidth',500)
df3=pd.DataFrame({'description':[" Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills in students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical, and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science, data analytics, and big data industry including cloud infrastructure and real-time industry projects."]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description
# ...

# %%
#ebar width change korchi
#solution:
pd.set_option('display.max_colwidth',1000)
df3=pd.DataFrame({'description':[" Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills in students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical, and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science, data analytics, and big data industry including cloud infrastructure and real-time industry projects."]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           description
# ...

# %%
#dekho puro ta dekha jachhe na
#solution:
pd.set_option('display.max_colwidth',500)
df3=pd.DataFrame({'description':[" Data Science Masters course is highly curated and uniquely designed according to the latest industry standards." ,"This program instills in students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical, and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science", "data analytics, and big data industry including cloud infrastructure and real-time industry projects."]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description
# ...

# %%
#now we want the length of data:
df3['length']=df3['description'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description  \
# ...

# %%
#say we have a string and you have to find number of words:
t="Fc bayern munich home ground is allianz arena"
t.split()
#jekhane space pabe , tar por segulo ke list e rakhbe
print(t.split())
print("words:",  len( t.split() ) )
# Out:
# ['Fc', 'bayern', 'munich', 'home', 'ground', 'is', 'allianz', 'arena']
# words: 8

# %%
#now I want to know how many words are there :
df3['word_count']=df3['description'].apply(lambda x: len(x.split()))

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description  \
# ...

# %%
df
# Out:
#    a  b        c
# 0  1  4   muller
# 1  2  5    neuer
# 2  3  6    kroos
# 3  4  7  musiala

# %% [markdown]
# Use statistical functions

# %%
#now find mean of column a values:
df['a'].mean()
# Out:
# 2.5

# %%
df['a'].median()
# Out:
# 2.5

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
#standard deviation:
df['a'].std()
# Out:
# 1.2909944487358056

# %%
df['a'].sum()
# Out:
# 10

# %%
df['a'].min()
# Out:
# 1

# %%
df['a'].max()
# Out:
# 4

# %% [markdown]
# Now let's see some more examples:

# %%
df4=pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %% [markdown]
# Python pandas - window functions

# %%
df4['a'].rolling(window=1).mean()
#same data print koray
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
#eta first duto data avg nebe
#(nan+3.0)/2= nan
#(3.0+4.0)/2=3.5
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).mean()
#ei khane 3 te data niye mean ber korche
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
#python pandas date functionality:
date=pd.date_range(start='2023-04-23', end='2023-06-23')

# %%
#date genrate korbe oi range e
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
#convert this to data frame:
df_date=pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
#another case:
#let's take date in string format
df7=pd.DataFrame({'date':['2023-06-19','2023-06-20','2023-06-21']})

# %%
df7
# Out:
#          date
# 0  2023-06-19
# 1  2023-06-20
# 2  2023-06-21

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
#df7 string e ache , ebar etake date time e convert korbo:
df7['updated_date']=pd.to_datetime(df7['date'])

# %%
df7.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
#find the year:
df7['year']=df7['updated_date'].dt.year

# %%
df7
# Out:
#          date updated_date  year
# 0  2023-06-19   2023-06-19  2023
# 1  2023-06-20   2023-06-20  2023
# 2  2023-06-21   2023-06-21  2023

# %%
#let's say you want to find the day:
df7['day']=df7['updated_date'].dt.day
df7['month']=df7['updated_date'].dt.month

# %%
df7
# Out:
#          date updated_date  year  day  month
# 0  2023-06-19   2023-06-19  2023   19      6
# 1  2023-06-20   2023-06-20  2023   20      6
# 2  2023-06-21   2023-06-21  2023   21      6

# %% [markdown]
# ## time delta in pyhton

# %%
pd.Timedelta(days=1)
# Out:
# Timedelta('1 days 00:00:00')

# %%
pd.Timedelta(days=1,hours=5)
# Out:
# Timedelta('1 days 05:00:00')

# %%
pd.Timedelta(days=1,hours=5,minutes=45, seconds =15)
# Out:
# Timedelta('1 days 05:45:15')

# %%
dt=pd.to_datetime('2023-06-23')
dt
# Out:
# Timestamp('2023-06-23 00:00:00')

# %%
#timeDelta
td=pd.Timedelta(days=1)
td
# Out:
# Timedelta('1 days 00:00:00')

# %%
dt+td
# Out:
# Timestamp('2023-06-24 00:00:00')

# %% [markdown]
# ##categorical data

# %%
data=['neuer','muller','kroos','schweinsteiger','muller']

# %%
#let's see how many unique datas are there:
cat=pd.Categorical(data)
cat
# Out:
# ['neuer', 'muller', 'kroos', 'schweinsteiger', 'muller']
# Categories (4, object): ['kroos', 'muller', 'neuer', 'schweinsteiger']

# %%
cat.value_counts()
# Out:
# kroos             1
# muller            2
# neuer             1
# schweinsteiger    1
# dtype: int64

# %% [markdown]
# ##pandas visualaization

# %%
d=pd.Series([1,3,2,4,6,5])

# %%
d
# Out:
# 0    1
# 1    3
# 2    2
# 3    4
# 4    6
# 5    5
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame({'a':[3,4,5,6,7],
                 'b':[10,11,12,13,14]})

# %%
df
# Out:
#    a   b
# 0  3  10
# 1  4  11
# 2  5  12
# 3  6  13
# 4  7  14

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>
